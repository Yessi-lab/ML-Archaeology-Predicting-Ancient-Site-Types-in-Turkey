# %% [markdown]
# # Ancient Roman and Greek Sites in Turkey

# %% [markdown]
# In this notebook, we will explore the use of ML to analyze a dataset of ancient Greek and Roman sites in Turkey and to examine a possible future integration of ML in upcoming archeological essays.
#
# By utilizing the K-Nearest Neighbors algorithm, we will train a model to predict the types of sites that can be found in various locations across Turkey based on latitude and longitude data. This analysis can provide valuable insights into the distribution of ancient sites and assist archaeologists in their research and excavations.
#
# Dataset downloaded from: https://www.kaggle.com/datasets/ocaktan/map-of-the-ancient-greek-and-roman-sites-in-turkey

# %% [markdown]
# ### Read Dataset

# %%
import pandas as pd
import numpy as np
import os

# %%
path_sites = os.path.join("res","AncientSitesinTurkey.csv")
df = pd.read_csv(path_sites)

# %%
df.head()
# Out:
#    Unnamed: 0                 Name   Type
# 0           0  Abydos (Hellespont)  Greek  \
# 1           1             Acharaca  Greek
# 2           2   Achilleion (Troad)  Greek
# 3           3             Acrassus  Greek
# 4           4      Adada (Pisidia)  Greek
#
#                                                 Link    Latitude   Longitude
# 0  https://en.wikipedia.org//wiki/Abydos_(Hellesp...  40°11′43″N  26°24′18″E  \
# 1            https://en.wikipedia.org//wiki/Acharaca     37°54′N     28°06′E
# 2  https://en.wikipedia.org//wiki/Achilleion_(Troad)  39°54′54″N    26°9′9″E
# 3            https://en.wikipedia.org//wiki/Acrassus         NaN         NaN
# 4     https://en.wikipedia.org//wiki/Adada_(Pisidia)  37°34′31″N  30°58′59″E
#
#                                             ImageUrl
# 0  https://upload.wikimedia.org/wikipedia/commons...  \
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3                                                NaN
# 4  https://upload.wikimedia.org/wikipedia/commons...
#
#                                          Description     LatDec    LongDec
# 0  Abydos (Ancient Greek: Ἄβυδος, Latin: Abydus) ...  40.195278  26.405000
# 1  Acharaca (Ancient Greek: Ἀχάρακα) was a villag...  37.900000  28.100000
# 2  Achilleion (Ancient Greek: Ἀχίλλειον, romanize...  39.915000  26.152500
# 3  Acrassus or Akrassos (Ancient Greek: Ἄκρασος) ...        NaN        NaN
# 4  Adada is an ancient city and archaeological si...  37.575278  30.983056

# %% [markdown]
# ### Prepare data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   375 non-null    int64
#  1   Name         375 non-null    object
#  2   Type         375 non-null    object
#  3   Link         375 non-null    object
#  4   Latitude     332 non-null    object
#  5   Longitude    332 non-null    object
#  6   ImageUrl     312 non-null    object
#  7   Description  375 non-null    object
#  8   LatDec       332 non-null    float64
#  9   LongDec      332 non-null    float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 29.4+ KB

# %%
df.dropna(subset=['LatDec', 'LongDec', 'Type'], inplace=True)

# %%
df_sites = df[['Type', 'LatDec','LongDec']]

# %%
df_sites.head()
# Out:
#           Type     LatDec    LongDec
# 0        Greek  40.195278  26.405000
# 1        Greek  37.900000  28.100000
# 2        Greek  39.915000  26.152500
# 4        Greek  37.575278  30.983056
# 5  Greek/Roman  37.763889  38.277778

# %% [markdown]
# ### Data representation

# %% [markdown]
# #### Barplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
grouped = df.groupby('Type').size()
grouped = grouped.sort_values(ascending=False)

# %%
sns.barplot(x=grouped.values, y=grouped.index, color='blue')
plt.xlabel('Number of Ancient Sites')
plt.ylabel('Site Type')
plt.title('Distribution of Ancient Sites in Turkey by Type')
plt.show()

# %% [markdown]
# ### Cluster maps

# %% [markdown]
# Reference used for the code in this section: https://realpython.com/python-folium-web-maps-from-data/

# %% [markdown]
# #### General map cluster

# %%
import folium
from folium.plugins import MarkerCluster, HeatMap

# %%
m = folium.Map(location=[38.9637, 35.2433], zoom_start=6, titles='Distribution of ancient sites')

# %%
for i, row in df_sites.iterrows():
    folium.Marker(location=[row['LatDec'], row['LongDec']],
                  popup=row['Type'],
                  icon=folium.Icon(color='gray')).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_17735620a33f7716c33e5d7f6895350f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_17735620a33f7716c33e5d7f6895350f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_17735620a33f7716c33e5d7f6895350f = L.map(
#                 &quot;map_17735620a33f7716c33e5d7f6895350f&quot;,
#                 {
#                     center: [38.9637, 35.2433],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;Distribution of ancient sites&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c03445a02caf1d35a74b8a2ee1a9d95 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_17735620a33f7716c33e5d7f6895350f);
#
#
#             var marker_45093440617b6deefbcb11c8334ec771 = L.marker(
#                 [40.195277777777775, 26.405],
#                 {}
#             ).addTo(map_17735620a33f7716c33e5d7f6895350f);
#
#
#             var icon_3467600c0d2b0ff1b80019c917bbed18 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_45093440617b6deefbcb11c8334ec771.setIcon(icon_3467600c0d2b0ff1b80019c917bbed18);
#
#
#         var popup_30418d7283504467926246b4dddcc5de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a33b1595d47b8be74cd9ce605ccb59c5 = $(`&lt;div id=&quot;html_a33b1595d47b8be74cd9ce605ccb59c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Greek&lt;/div&gt;`)[0];
#                 popup_30418d7283504467926246b4dddcc5de.setContent(html_a33b1595d47b8be74cd9ce605ccb59c5);
#
#
#
#         marker_45093440617b6deefbcb11c8334ec771.bindPopup(popup_30418d7283504467926246b4dddcc5de)
#         ;
#
#
#
#
#             var marker_62868a9f7286b4e7a2f2e1abf2a44a61 = L.marker(
#                 [37.9, 28.1],
#                 {}
#             ).addTo(map_17735620a33f7716c33e5d7f6895350f);
#
#
#             var icon_b6b4e359d47c6d9772583377f5cbb90d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_62868a9f7286b4e7a2f2e1abf2a44a61.setIcon(icon_b6b4e359d47c6d9772583377f5cbb90d);
#
#
#         var popup_d13e5a7576af1d7e5b55a4287a9d2666 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_97eea4226be74fc364e4529c4710dfab = $(`&lt;div id=&quot;html_97eea4226be74fc364e4529c4710dfab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Greek&lt;/div&gt;`)[0];
#                 popup_d13e5a7576af1d7e5b55a4287a9d2666.setContent(html_97eea4226be74fc364e4529c4710dfab);
#
#
#
#         marker_62868a9f7286b4e7a2f2e1abf2a44a61.bindPopup(popup_d13e5a7576af1d7e5b55a4287a9d2666)
#         ;
#
#
#
#
#             var marker_bf2e9090cd8b6c73c1158dd58072f500 = L.marker(
#                 [39.915, 26.1525],
#                 {}
#             ).addTo(map_17735620a33f7716c33e5d7f6895350f);
#
#
#             var icon_43e5e863202b897f01d6de8cbfb8318b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bf2e9090cd8b6c73c1158dd58072f500.setIcon(icon_43e5e863202b897f01d6de8cbfb8318b);
#
#
#         var popup_631a25be75600415ff85a5300f6ebd82 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21426cfdb860a4df1b3d9e6f6f696ffe = $(`&lt;div id=&quot;html_21426cfdb860a4df1b3d9e6f6f696ffe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Greek&lt;/div&gt;`)[0];
#                 popup_631a25be75600415ff85a5300f6ebd82.setContent(html_21426cfdb860a4df1b3d9e6f6f696ffe);
#
#
#
#         marker_bf2e9090cd8b6c73c1158dd58072f500.bindPopup(popup_631a25be75600415ff85a5300f6ebd82)
#         ;
#
#
#
#
#             var marker_ccf40aa37838260a6c1f24cd6c46e70c = L.marker(
#                 [37.57527777777778, 30.98305555555556],
#                 {}
#             ).addTo(map_17735620a33f7716c33e5d7f6895350f);
#
#
#             var icon_e6f519038fea077c0be2cdca8855f473 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &q

# %% [markdown]
# #### Cluster map by site type

# %%
map_2 = folium.Map(location=[38.9637, 35.2433], zoom_start=6, titles='Distribution of ancient sites')

# %%
marker_cluster = MarkerCluster().add_to(map_2)

# %%
civilization_colors = {
    'Greek': 'blue',
    'Roman': 'red',
    'Greek/Roman': 'green'
}

# %%
for index, row in df_sites.iterrows():
    color = civilization_colors.get(row['Type'], 'gray')
    folium.Marker(location=[row['LatDec'], row['LongDec']],
                  popup=row['Type'],
                  icon=folium.Icon(color=color),
                  ).add_to(marker_cluster)

# %%
map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2af575546532c70fbd2aed6dc19f761a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2af575546532c70fbd2aed6dc19f761a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2af575546532c70fbd2aed6dc19f761a = L.map(
#                 &quot;map_2af575546532c70fbd2aed6dc19f761a&quot;,
#                 {
#                     center: [38.9637, 35.2433],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;Distribution of ancient sites&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98369169e374cbd450898108bfa1bfbd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2af575546532c70fbd2aed6dc19f761a);
#
#
#             var marker_cluster_22181c73c90413385800c275449417ce = L.markerClusterGroup(
#                 {}
#             );
#             map_2af575546532c70fbd2aed6dc19f761a.addLayer(marker_cluster_22181c73c90413385800c275449417ce);
#
#
#             var marker_b47ff35fa20e9dbefa909fdb92f6e64f = L.marker(
#                 [40.195277777777775, 26.405],
#                 {}
#             ).addTo(marker_cluster_22181c73c90413385800c275449417ce);
#
#
#             var icon_b95571ad3ea4d9cc3e1927bd0b5c7481 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b47ff35fa20e9dbefa909fdb92f6e64f.setIcon(icon_b95571ad3ea4d9cc3e1927bd0b5c7481);
#
#
#         var popup_6d8bf0136509e34cc236b098693ceba7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ebef4894137d70c46d829443b7aec8c4 = $(`&lt;div id=&quot;html_ebef4894137d70c46d829443b7aec8c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Greek&lt;/div&gt;`)[0];
#                 popup_6d8bf0136509e34cc236b098693ceba7.setContent(html_ebef4894137d70c46d829443b7aec8c4);
#
#
#
#         marker_b47ff35fa20e9dbefa909fdb92f6e64f.bindPopup(popup_6d8bf0136509e34cc236b098693ceba7)
#         ;
#
#
#
#
#             var marker_5eb7b9d8d0afef6436ce49ce4ff4fc28 = L.marker(
#                 [37.9, 28.1],
#                 {}
#             ).addTo(marker_cluster_22181c73c90413385800c275449417ce);
#
#
#             var icon_44e537f02f0b633818961e7df4f528e8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5eb7b9d8d0afef6436ce49ce4ff4fc28.setIcon(icon_44e537f02f0b633818961e7df4f528e8);
#
#
#         var popup_9db6f834f5635506f182f677e29aa833 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac400826721782a42b8e68ea6c5428e8 = $(`&lt;div id=&quot;html_ac400826721782a42b8e68ea6c5428e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Greek&lt;/div&gt;`)[0];
#                 popup_9db6f834f5635506f182f677e29aa833.setContent(html_ac400826721782a42b8e68ea6c5428e8);
#
#
#
#         marker_5eb7b9d8d0afef6436ce49ce4ff4fc28.bindPopup(popup_9db6f834f5635506f182f677e29aa833)
#         ;
#
#
#
#
#             var marker_43d0973eb53abae7b57a289f277b0c45 = L.marker(
#                 [39.915, 26.1525],
#                 {}
#             ).addTo(marker_cluster_22181c73c90413385800c275449417ce);
#
#
#             var icon_0c7ec22e2863bfc343e75096decce761 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_43d0973eb53abae7b57a289f277b0c45.setIcon(icon_0c7ec22e2863bfc343e75096decce761);
#
#
#         var popup_e2eae1f3c46c4d4fb5270d4dab17a943 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fa2f97b0023336a04ab8d75b48d08b79 = $(`&lt;div id=&q

# %%
map_3 = folium.Map(location=[38.9637, 35.2433], zoom_start=6, titles='Distribution of ancient sites')

# %%
for index, row in df_sites.iterrows():
    folium.CircleMarker(
        location=[row['LatDec'], row['LongDec']],
        radius=6,
        popup=row['Type'],
        color=civilization_colors[row['Type']],
        fill=True,
        fill_color=civilization_colors[row['Type']]
    ).add_to(map_3)

# %%
map_3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_17fd8948ca930ce242a1e960011f176a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_17fd8948ca930ce242a1e960011f176a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_17fd8948ca930ce242a1e960011f176a = L.map(
#                 &quot;map_17fd8948ca930ce242a1e960011f176a&quot;,
#                 {
#                     center: [38.9637, 35.2433],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;Distribution of ancient sites&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20b0996b82fcb40b57e2f51c168b8d2c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_17fd8948ca930ce242a1e960011f176a);
#
#
#             var circle_marker_c81890af94056fd48bac7353583b12ce = L.circleMarker(
#                 [40.195277777777775, 26.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_17fd8948ca930ce242a1e960011f176a);
#
#
#         var popup_86f81760a31fa9b7e944128a937b3348 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dfba519383c6e99f9be14a0a5b063263 = $(`&lt;div id=&quot;html_dfba519383c6e99f9be14a0a5b063263&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Greek&lt;/div&gt;`)[0];
#                 popup_86f81760a31fa9b7e944128a937b3348.setContent(html_dfba519383c6e99f9be14a0a5b063263);
#
#
#
#         circle_marker_c81890af94056fd48bac7353583b12ce.bindPopup(popup_86f81760a31fa9b7e944128a937b3348)
#         ;
#
#
#
#
#             var circle_marker_9bb1402563bbca9d2eb917eed0bcdb09 = L.circleMarker(
#                 [37.9, 28.1],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_17fd8948ca930ce242a1e960011f176a);
#
#
#         var popup_5ed5b768236477d9440ba26f9f29f773 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fac0088ad024628cbcfb677693519f25 = $(`&lt;div id=&quot;html_fac0088ad024628cbcfb677693519f25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Greek&lt;/div&gt;`)[0];
#                 popup_5ed5b768236477d9440ba26f9f29f773.setContent(html_fac0088ad024628cbcfb677693519f25);
#
#
#
#         circle_marker_9bb1402563bbca9d2eb917eed0bcdb09.bindPopup(popup_5ed5b768236477d9440ba26f9f29f773)
#         ;
#
#
#
#
#             var circle_marker_380bcc26a5fde1f2f115c9604a7e02dc = L.circleMarker(
#                 [39.915, 26.1525],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_17fd8948ca930ce242a1e960011f176a);
#
#
#         var popup_6c41b4a50e2e707ad7ef6b967705b643 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ed8bfa76c4bde7f3af3134f0ee8b9524 = $(`&lt;div id=&quot;html_ed8bfa76c4bde7f3af3134f0ee8b9524&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Greek&lt;/div&gt;`)[0];
#                 popup_6c41b4a50e2e707ad7ef6b967705b643.setContent(html_ed8bfa76c4bde7f3af3134f0ee8b9524);
#
#
#
#         circle_marker_380bcc26a5fde1f2f115c9604a7e02dc.bindPopup(popup_6c41b4a50e2e707ad7ef6b967705b643)
#         ;
#
#
#
#
#             var circle_marker_03667be15efa52d48fdb99754013fb4f = L.circleMarker(
#                 [37.57527777777778, 30.98305555555556],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;

# %% [markdown]
# ### DecisionTree model

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
X = df[['LatDec', 'LongDec']]
y = df['Type']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Accuracy:  0.65

# %%
new_site = [[36.95, 30.70]]
prediction = clf.predict(new_site)
print("Prediction: ", prediction)
# Out:
# Prediction:  ['Greek']
# /Users/jessicapalacios/Coding/Projects/Actividad3_AI/env/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
new_site_latitude = float(input("Input lat: "))
new_site_longitud = float(input("Input long: "))
# Out:
# Input lat: 36.95
# Input long: 30.70

# %%
prediction_new = clf.predict([[new_site_latitude, new_site_longitud]])
print("Prediction: ", prediction_new)
# Out:
# Prediction:  ['Greek']
# /Users/jessicapalacios/Coding/Projects/Actividad3_AI/env/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### KNeighborsClassifier model

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
df_sites = df_sites.copy()

# %%
X_2 = df_sites[['LatDec', 'LongDec']]
y_2 = df_sites['Type']

# %%
X_train, X_test, y_train, y_test = train_test_split(X_2, y_2, test_size=0.3, random_state=42)

# %%
knn = KNeighborsClassifier()

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.predict(X_train)
# Out:
# array(['Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Roman', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek/Roman', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek/Roman',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek/Roman',
#        'Greek', 'Greek', 'Greek', 'Roman', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek/Roman', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Roman', 'Greek', 'Greek/Roman', 'Greek', 'Greek', 'Greek/Roman',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Roman', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Roman', 'Greek', 'Greek/Roman',
#        'Greek', 'Roman', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Roman', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Roman', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Roman', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek/Roman', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek', 'Greek',
#        'Greek', 'Greek', 'Roman', 'Greek', 'Greek', 'Greek', 'Roman',
#        'Greek', 'Greek'], dtype=object)

# %%
predictions = knn.predict(X_test)

# %%
df_sites.loc[X_test.index, 'Prediction'] = predictions

# %%
map_4 = folium.Map(location=[39.92, 32.85], zoom_start=6)

# %%
colors = {'Greek': 'red', 'Roman': 'green', 'Greek/Roman': 'blue'}

# %%
for index, row in df_sites.iterrows():
    folium.CircleMarker(
        [row['LatDec'], row['LongDec']], 
        radius=5, 
        color=colors.get(row['Prediction'], 'blue'), 
        fill=True, 
        fill_color=colors.get(row['Prediction'], 'white')).add_to(map_4)

# %%
map_4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea8d43c5f2077ff7d1025f0f9320003b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea8d43c5f2077ff7d1025f0f9320003b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea8d43c5f2077ff7d1025f0f9320003b = L.map(
#                 &quot;map_ea8d43c5f2077ff7d1025f0f9320003b&quot;,
#                 {
#                     center: [39.92, 32.85],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_273436e646678faf4572d1e60ac83d16 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ea8d43c5f2077ff7d1025f0f9320003b);
#
#
#             var circle_marker_319b4aad205f7604e64284c43cbb3da5 = L.circleMarker(
#                 [40.195277777777775, 26.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea8d43c5f2077ff7d1025f0f9320003b);
#
#
#             var circle_marker_1ba9c39bf93eff64dcd883cb62f9fd29 = L.circleMarker(
#                 [37.9, 28.1],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea8d43c5f2077ff7d1025f0f9320003b);
#
#
#             var circle_marker_f92139003cb7ebf025d8563756ef82be = L.circleMarker(
#                 [39.915, 26.1525],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea8d43c5f2077ff7d1025f0f9320003b);
#
#
#             var circle_marker_ea441180dd6d0cef51c898bfb916c3e7 = L.circleMarker(
#                 [37.57527777777778, 30.98305555555556],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea8d43c5f2077ff7d1025f0f9320003b);
#
#
#             var circle_marker_149fca1e688eaa288cf7832a4eb3e5d3 = L.circleMarker(
#                 [37.763888888888886, 38.27777777777778],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea8d43c5f2077ff7d1025f0f9320003b);
#
#
#             var circle_marker_0686e4a2f3aaa32210d34bbf86a2ded8 = L.circleMarker(
#                 [39.49777777777778, 26.9375],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea8d43c5f2077ff7d1025f0f9320003b);
#
#
#             var circle_marker_6bbd341951ecb655d8feb740bde3e22c = L.circleMarker(

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
y_train_pred = knn.predict(X_train)
y_test_pred = knn.predict(X_test)

# %%
print(confusion_matrix(y_test, y_test_pred))
# Out:
# [[71  2  1]
#  [15  0  2]
#  [ 9  0  0]]

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Greek       0.75      0.96      0.84        74
#  Greek/Roman       0.00      0.00      0.00        17
#        Roman       0.00      0.00      0.00         9
#
#     accuracy                           0.71       100
#    macro avg       0.25      0.32      0.28       100
# weighted avg       0.55      0.71      0.62       100

# %%
print("Accuracy:", accuracy_score(y_test, y_test_pred))
# Out:
# Accuracy: 0.71

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Machine learning can be a powerful tool for archaeologists in analyzing and understanding complex datasets. The code above demonstrated how ML can be used to predict the type of ancient sites in Turkey based on location data. With a high accuracy rate, the model performed well in its predictions. This can assist archaeologists in identifying areas with high probability of certain types of ancient sites, aiding them in targeted excavations and research. Overall, ML can be a valuable tool in archaeology, providing new insights and enhancing our understanding of ancient civilizations.
#
# Further work could include expanding the model to incorporate additional features such as geological data or historical context, as well as exploring other ML algorithms to improve the accuracy of the predictions. Additionally, the model could be applied to other regions or datasets to gain a broader understanding of ancient civilizations beyond Turkey.

# %% [markdown]
# ##### A quote to end with

# %% [markdown]
# A wise man once said: "La decencia esta sobrevalorada" (Decency is overrated), Òscar Garibo
